# %%
# !python -h
# Out:
# usage: python3 [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Options and arguments (and corresponding environment variables):
# -b     : issue warnings about str(bytes_instance), str(bytearray_instance)
#          and comparing bytes/bytearray with str. (-bb: issue errors)
# -B     : don't write .pyc files on import; also PYTHONDONTWRITEBYTECODE=x
# -c cmd : program passed in as string (terminates option list)
# -d     : debug output from parser; also PYTHONDEBUG=x
# -E     : ignore PYTHON* environment variables (such as PYTHONPATH)
# -h     : print this help message and exit (also --help)
# -i     : inspect interactively after running script; forces a prompt even
#          if stdin does not appear to be a terminal; also PYTHONINSPECT=x
# -I     : isolate Python from the user's environment (implies -E and -s)
# -m mod : run library module as a script (terminates option list)
# -O     : remove assert and __debug__-dependent statements; add .opt-1 before
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 버전 설치

# !git clone https://github.com/AISangam/Mask-RCNN-bottle-training.git
# %cd Mask_RCNN
# Out:
# Cloning into 'Mask-RCNN-bottle-training'...
# remote: Enumerating objects: 97, done.
# remote: Total 97 (delta 0), reused 0 (delta 0), pack-reused 97
# Unpacking objects: 100% (97/97), done.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YnfvRHjDGCRov5uKfCW3")
project = rf.workspace("minsoung93").project("strawberry_-last")
dataset = project.version(3).download("coco")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 145 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 178 kB 50.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 49.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 138 kB 61.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.8 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.3 MB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.4-py3-none-any.whl size=21356 sha256=7093de78230bb19c586a174d19a9d4929cc80ce8996c85a8698e821177437135
#   Stored in directory: /root/.cache/pip/wheels/b7/2c/60/3733c0e323b1d7aec00f852264314bf6c48192c8e1dc92b3ee
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=927d57137eaac3fca5fc3a47ce2b5d55353f3b4ec3819006e70bd6d27f61d36c
# ...

# %%
# %cd /content
# !git clone https://github.com/matterport/Mask_RCNN
# %cd /content/Mask_RCNN
# !python setup.py install
# Out:
# /content
# fatal: destination path 'Mask_RCNN' already exists and is not an empty directory.
# /content/Mask_RCNN
# WARNING:root:Fail load requirements file, so using default ones.
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'license-file' will not be supported in future versions. Please use the underscore name 'license_file' instead
#   % (opt, underscore_opt))
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'requirements-file' will not be supported in future versions. Please use the underscore name 'requirements_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# ...

# %%
# !pwd
# Out:
# /content/Mask_RCNN

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 462 kB 8.8 MB/s
#      |████████████████████████████████| 296 kB 47.5 MB/s
#      |████████████████████████████████| 154 kB 54.9 MB/s

# %%
# install tf,keras version
# !pip install tensorflow-gpu==1.15.0
# !pip install keras==2.2.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 411.5 MB 6.5 kB/s
# ...
#      |████████████████████████████████| 503 kB 53.3 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 54.0 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=db8ae8509c95c1ef62fc6e1eb759982957eb6ee4c25cb07d679ab1d85e994e13
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
# ...

# %%
# %cd /content/Mask-RCNN-bottle-training
# !python bottle.py train --dataset="/content/Strawberry_-last-3"  --weight=coco
# Out:
# /content/Mask-RCNN-bottle-training
# Using TensorFlow backend.
# Weights:  coco
# Dataset:  /content/Strawberry_-last-3
# Logs:  /logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                19
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
# !python val.py --weights runs/train/pothole_results/weights/best.pt --data ./pothole/data.yaml --img 640 --task test

# %%
# !python detect.py --weights runs/train/pothole_results/weights/best.pt --img 640 --conf 0.4 --source ./pothole/test/images

# %%
import glob
import random

image_name = random.choice(glob.glob('/content/yolov5/runs/detect/exp2/*.jpg'))
display(Image(filename=image_name))

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# 모델 내보내기

# %mkdir /content/drive/MyDrive/CAKD5/SW/m10_딥러닝응용/pothole
# %cp /content/yolov5/runs/train/pothole_results/weights/best.pt /content/drive/MyDrive/CAKD5/SW/m10_딥러닝응용/pothole
