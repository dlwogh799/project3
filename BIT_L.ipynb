# %%
# !python -h
# Out:
# usage: python3 [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Options and arguments (and corresponding environment variables):
# -b     : issue warnings about str(bytes_instance), str(bytearray_instance)
#          and comparing bytes/bytearray with str. (-bb: issue errors)
# -B     : don't write .pyc files on import; also PYTHONDONTWRITEBYTECODE=x
# -c cmd : program passed in as string (terminates option list)
# -d     : debug output from parser; also PYTHONDEBUG=x
# -E     : ignore PYTHON* environment variables (such as PYTHONPATH)
# -h     : print this help message and exit (also --help)
# -i     : inspect interactively after running script; forces a prompt even
#          if stdin does not appear to be a terminal; also PYTHONINSPECT=x
# -I     : isolate Python from the user's environment (implies -E and -s)
# -m mod : run library module as a script (terminates option list)
# -O     : remove assert and __debug__-dependent statements; add .opt-1 before
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 버전 설치

# !git clone https://github.com/google-research/big_transfer
# %cd /content/drive/MyDrive/MKS/project3/big_transfer-master/big_transfer-master
# !pip install -r bit_pytorch/requirements.txt
# Out:
# /content/drive/MyDrive/MKS/project3/big_transfer-master/big_transfer-master
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !wget https://storage.googleapis.com/bit_models/BiT-M-R50x1.npz
# Out:
# --2022-05-26 05:52:49--  https://storage.googleapis.com/bit_models/BiT-M-R50x1.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.153.128, 108.177.127.128, 172.217.218.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.153.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 273071896 (260M) [application/octet-stream]
# Saving to: ‘BiT-M-R50x1.npz’
#
# BiT-M-R50x1.npz     100%[===================>] 260.42M  77.3MB/s    in 3.4s
#
# 2022-05-26 05:52:52 (77.0 MB/s) - ‘BiT-M-R50x1.npz’ saved [273071896/273071896]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YnfvRHjDGCRov5uKfCW3")
project = rf.workspace("minsoung93").project("strawberry_-last")
dataset = project.version(6).download("tensorflow")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 145 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 178 kB 30.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 77.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.5 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 91.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 70.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.0 MB/s
# ...
#   Created wheel for roboflow: filename=roboflow-0.2.4-py3-none-any.whl size=21356 sha256=efc00160ace29427f46b324cff83b9409707e47be6a9949cfc0c650987c8b78e
#   Stored in directory: /root/.cache/pip/wheels/b7/2c/60/3733c0e323b1d7aec00f852264314bf6c48192c8e1dc92b3ee
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=4546847eb15fdbfe54895fd8576c365d5baae2fe8010c7b285c09fb4d34fb75b
# ...

# %%
# %cd /content/drive/MyDrive/big_transfer-master
# Out:
# /content/big_transfer

# %%
# !pip install transforms
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for transforms: filename=transforms-0.1-py3-none-any.whl size=39351 sha256=d74eb7556f02181617ed3beacc3831650f81ede832c13560a2aacb03ee144eee
#   Stored in directory: /root/.cache/pip/wheels/73/8d/26/be8b7e278f01d5093d18fc99c8158bd8528403242c852a558c
# Successfully built transforms
# ...

# %%
# !pip install sgmllib3k
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=b57739417c5ad7479baa7528c3e17c76864fa8b833b248b9931f2e422bcbf004
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built sgmllib3k
# ...

# %%
# !python -m bit_pytorch.train --name custom_classifier --model BiT-M-R50x1 --logdir /tmp/bit_logs --dataset customDataset
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/drive/MyDrive/MKS/project3/big_transfer-master/big_transfer-master/bit_pytorch/train.py", line 36, in <module>
#     transform = transforms.ToTensor())
# AttributeError: module 'transforms' has no attribute 'ToTensor'
